# %% [markdown]
# # Testando...som, som, som 123

# %%
import requests
import json


token_id = "ee9f1165-a342-430c-b4af-aaf19310a207"
headers = {"api-key": "df827879-b9d3-47f2-a73b-abd44b63c6e5"}

r = requests.get(f'https://webhook.site/token/{token_id}/requests?sorting=newest', headers=headers)
response_json = r.json()

key_value_map = {}

# Define a function to recursively iterate over each level of the JSON object
def iterate_json(data, indent=0):
    if isinstance(data, dict):
        for key, value in data.items():
            key_name = key
            #print(' ' * indent + f'{key_name}:')
            
            key_value_map[key] = value
            if key == 'content':
                iterate_json(json.loads(value), indent=indent+2)
                key_value_map[key] = value
            else:
                iterate_json(value, indent=indent+2)
                key_value_map[key] = value

            key_value_map[key] = value
                
    elif isinstance(data, list):
        for item in data:
            iterate_json(item, indent=indent+2)
    else:
        key_value = str(data)
        #print('      ' * indent + key_value)
        

# Call iterate_json on each request dictionary in the JSON response
for request in r.json()['data']:
    iterate_json(request)
    
    #print('----------------------')
    
messageType = key_value_map['messageType']
uuid = key_value_map['uuid']
ip = key_value_map['ip']
jid = key_value_map['jid']
preJid = key_value_map['jid']
jid = preJid.split(":")[0]
pushname = key_value_map['pushName']
fromMe = key_value_map['fromMe']



if messageType == 'audioMessage':
    pesquisa = key_value_map.get("audioMessage", "")
    media_key = pesquisa.get("mediaKey", "")
    direct_path = pesquisa.get("directPath", "")
    url = pesquisa.get('url','')
    mimetype = pesquisa.get("mimetype", "")
    message_type = key_value_map.get("messageType", "")
    message_type = 'audio'
    #cria payload para request    
    payload = json.dumps({
        "messageKeys": {
        "mediaKey": media_key,
        "directPath": direct_path,
        "url": url,
        "mimetype": mimetype,
        "messageType": message_type
        }
    })

    print(f'Mensagem do tipo: {messageType}\n')
    print(uuid)
    print(pushname)
    print(ip)
    print(jid)
    print(preJid)
    print(fromMe)
    print()
    print(payload)    
elif messageType == 'conversation':
    mensagem = key_value_map['message']
    conversa = key_value_map['conversation']
    
    print(f'Mensagem do tipo: {messageType}')
    print(uuid)
    print(pushname)
    print(ip)
    print(jid)
    print(preJid)
    print(fromMe)
    print()
    print(conversa)

# %%
import requests
import json


token_id = "ee9f1165-a342-430c-b4af-aaf19310a207"
headers = {"api-key": "df827879-b9d3-47f2-a73b-abd44b63c6e5"}

r = requests.get(f'https://webhook.site/token/{token_id}/requests?sorting=newest', headers=headers)
response_json = r.json()

key_value_map = {}

# Define a function to recursively iterate over each level of the JSON object
def iterate_json(data, indent=0):
    if isinstance(data, dict):
        for key, value in data.items():
            key_name = key
            #print(' ' * indent + f'{key_name}:')
            
            key_value_map[key] = value
            if key == 'content':
                iterate_json(json.loads(value), indent=indent+2)
                key_value_map[key] = value
            else:
                iterate_json(value, indent=indent+2)
                key_value_map[key] = value

            key_value_map[key] = value
                
    elif isinstance(data, list):
        for item in data:
            iterate_json(item, indent=indent+2)
    else:
        key_value = str(data)
        #print('      ' * indent + key_value)
        

# Call iterate_json on each request dictionary in the JSON response
for request in r.json()['data']:
    iterate_json(request)
    
    #print('----------------------')
    
messageType = key_value_map['messageType']
uuid = key_value_map['uuid']
ip = key_value_map['ip']
jid = key_value_map['jid']
preJid = key_value_map['jid']
jid = preJid.split(":")[0]
pushname = key_value_map['pushName']
fromMe = key_value_map['fromMe']



if messageType == 'audioMessage':
    pesquisa = key_value_map.get("audioMessage", "")
    media_key = pesquisa.get("mediaKey", "")
    direct_path = pesquisa.get("directPath", "")
    url = pesquisa.get('url','')
    mimetype = pesquisa.get("mimetype", "")
    message_type = key_value_map.get("messageType", "")
    message_type = 'audio'
    #cria payload para request    
    payload = json.dumps({
        "messageKeys": {
        "mediaKey": media_key,
        "directPath": direct_path,
        "url": url,
        "mimetype": mimetype,
        "messageType": message_type
        }
    })

    print(f'Mensagem do tipo: {messageType}\n')
    print(uuid)
    print(pushname)
    print(ip)
    print(jid)
    print(preJid)
    print(fromMe)
    print()
    print(payload)    
elif messageType == 'conversation':
    mensagem = key_value_map['message']
    conversa = key_value_map['conversation']
    
    print(f'Mensagem do tipo: {messageType}')
    print(uuid)
    print(pushname)
    print(ip)
    print(jid)
    print(preJid)
    print(fromMe)
    print()
    print(conversa)

# %%
key_value_map

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api5.megaapi.com.br")


headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer MOK9F6yvV9n0EvGIVsuvB7pPBA'
}


payload = {"messageKeys": 
                {"mediaKey": "Yl0EXI453CZNRqZ42X4uMB5wVXsBjp7ZXpmmQpIlB0M=", 
                 "directPath": "/v/t62.7117-24/34830436_973327023567065_4895249107891068489_n.enc?ccb=11-4&oh=01_AdQf3GtQAT16m5n6DuAJR5Zt3SO8Q_7rLIQGNqzRi1iFHA&oe=64395D98", 
                 "url": "https://mmg.whatsapp.net/v/t62.7117-24/34830436_973327023567065_4895249107891068489_n.enc?ccb=11-4&oh=01_AdQf3GtQAT16m5n6DuAJR5Zt3SO8Q_7rLIQGNqzRi1iFHA&oe=64395D98&mms3=true", 
                 "mimetype": "audio/ogg; codecs=opus", 
                 "messageType": "audio"
                 }
                }

conn.request("POST", "/rest/instance/downloadMediaMessage/megaapi-MOK9F6yvV9n0EvGIVsuvB7pPBA", payload, headers)

res = conn.getresponse()
data = res.read()

json_str = data.decode("utf-8")

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api5.megaapi.com.br")


headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer MOK9F6yvV9n0EvGIVsuvB7pPBA'
}

conn.request("POST", "/rest/instance/downloadMediaMessage/megaapi-MOK9F6yvV9n0EvGIVsuvB7pPBA", payload, headers)

res = conn.getresponse()
data = res.read()

json_str = data.decode("utf-8")

# %% [markdown]
# ### Convert to file

# %%
import base64
import json
import io
from openai import Audio
from pydub import AudioSegment

# Assume json_str contains the JSON data with the base64-encoded audio
json_dict = json.loads(json_str)

# Decode the base64-encoded audio data
audio_bytes_str = json_dict['data'].split(',')[1]

# Convert string to byte-string
audio_bytes = audio_bytes_str.encode('utf-8')

# Assume json_str contains the JSON data with the base64-encoded audio
json_dict = json.loads(json_str)

# Decode the base64-encoded audio data
audio_str = json_dict['data'].split(',')[1]

with open('/home/dani-boy/openai-quickstart-node/Sound/audioTeste.ogg', "wb") as f:
    f.write(base64.b64decode(audio_bytes))
    

def ogg2wav(ofn):
    wfn = ofn.replace('.ogg','.wav')
    x = AudioSegment.from_file(ofn)
    x.export(wfn, format='wav') 

ogg2wav('/home/dani-boy/openai-quickstart-node/Sound/audioTeste.ogg')

# %%
import openai

openai.api_key = "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"

#audio_file = open("/home/dani-boy/openai-quickstart-node/Sound/teste2-mp3-openai.mp3", "rb")

audio_file = open("/home/dani-boy/openai-quickstart-node/Sound/audioTeste.wav", "rb")


transcript = openai.Audio.transcribe("whisper-1", audio_file)


#translate = openai.Audio.translate("whisper-1", audio_file)



texto_transcrib = json.dumps(transcript)
data = json.loads(texto_transcrib)
mensagemTranscrita = data['text']
abertura = (f'Oi {pushname} aqui esta a sua mensagem:')


#text_translate = json.dumps(translate)
#dataTranslate = json.loads(text_translate)
#messageTranslated = dataTranslate['text']
#opening = 'in english' + messageTranslated

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api5.megaapi.com.br")


headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer MOK9F6yvV9n0EvGIVsuvB7pPBA'
}

payload = json.dumps({
  "messageData": {
    "to": preJid,
    "text": mensagemTranscrita
  }
})


conn.request("POST", "/rest/sendMessage/megaapi-MOK9F6yvV9n0EvGIVsuvB7pPBA/text", payload, headers)

res = conn.getresponse()
data = res.read()








print(data.decode("utf-8"))

# %%
"""Synthesizes speech from the input string of text or ssml.
Make sure to be working in a virtual environment.

Note: ssml must be well-formed according to:
    https://www.w3.org/TR/speech-synthesis/
"""
from google.cloud import texttospeech

# Instantiates a client
client = texttospeech.TextToSpeechClient()

# Set the text input to be synthesized
synthesis_input = texttospeech.SynthesisInput(text="mensagemTranscrita!")

# Build the voice request, select the language code ("en-US") and the ssml
# voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
)

# Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)

# Perform the text-to-speech request on the text input with the selected
# voice parameters and audio file type
response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)

# The response's audio_content is binary.
with open("output.mp3", "wb") as out:
    # Write the response to the output file.
    out.write(response.audio_content)
    print('Audio content written to file "output.mp3"')
